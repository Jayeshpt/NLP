# %%
import spacy
from spacy import displacy
from spacy.matcher import Matcher

nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('The quick brown fox jumps over the lazy dog')

for token in doc:
    print(token.text, '=', token.dep_, '=', token.head.text)
displacy.render(doc, style='dep', jupyter=True)
    
# root = doc.root
# print(root)
# Out:
# The = det = fox
# quick = amod = fox
# brown = amod = fox
# fox = nsubj = jumps
# jumps = ROOT = jumps
# over = prep = jumps
# the = det = dog
# lazy = amod = dog
# dog = pobj = over
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8f5b7ef8d56540b1b06bf1795266f36e-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">quick</tspan>
# ...

# %%
text = 'The big red apples on the table looks delicious.'

pattern = [{'DEP': 'amod', 'OP':'?'}, {'POS': 'ADJ', 'OP': '?'}, {'DEP': 'compound', 'OP': '?'}, {'POS': 'NOUN'}]

doc = nlp(text)

matches = []
# for chunk in doc.noun_chunks:
#     print('c---',chunk)
matcher = spacy.matcher.Matcher(nlp.vocab)
matcher.add('MATCH',  [pattern])
matches += matcher(chunk)
print(matches)
for match_id, start, end in matches:
    print(doc[start: end])
displacy.render(doc, style='dep', jupyter=True)
# Out:
# [(3670784538676273799, 1, 4), (3670784538676273799, 2, 4), (3670784538676273799, 3, 4)]
# big red apples
# red apples
# apples
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="81764c62275747159bc17c7a4a79c286-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">big</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# ...

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1e61adba4e2045c38f510d528a939329-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">big</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
text = "I bought a red car yesterday."

doc = nlp(text)

pattern = [{'DEP':'amod', 'OP': '?'}, {'POS': 'NOUN'}]
matcher.add('PATTERN',[pattern])

matches = matcher(doc)

for match_id, start, end in matches:
    print(doc[start:end])
displacy.render(doc, style='dep', jupyter=True)
# Out:
# red car
# car
# yesterday
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7d8063a43b6749ce9fdf6c9841052636-0" class="displacy" width="1100" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">bought</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
text = "She works at a large software company in San Francisco."
doc = nlp(text)

matcher = Matcher(nlp.vocab)

pattern = [{'POS': 'VERB'}, {'POS': 'ADP'}, {'DEP': 'det'}, {'DEP': 'amod'}, {'POS': 'NOUN', 'OP': '+'}]
matcher.add('PATTERN', [pattern])
matches = matcher(doc)

for match_id, start, end in matches:
    print(doc[start:end])
    
displacy.render(doc, style='dep', jupyter=True)
# Out:
# works at a large software
# works at a large software company
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0077b9f860f14788b095e0be9c858060-0" class="displacy" width="1800" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">She</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">works</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...
